# %%
import numpy as np 
import matplotlib.pyplot as plt
rgb = np.array([
    [[255,0,0],[255,0,0],[255,0,0]],
    [[0,255,0],[0,255,0],[0,255,0]],
    [[0,0,255],[0,0,255],[0,0,255]]
])
plt.imshow(rgb)
plt.show()

# %%
rgb_2 = np.array([
    [[255,0,0],[255,255,0],[255,255,255]],
    [[255,0,255],[0,255,0],[0,255,255]],
    [[0,0,0],[0,255,255],[0,0,255]]
])
plt.imshow(rgb_2)
plt.show()

# %%
with open('logo.npy','rb') as f:
    logo_rgb_array = np.load(f,allow_pickle = True)
    plt.imshow(logo_rgb_array)
    plt.show
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_npyio_impl.py:493, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     492 try:
# --> 493     return pickle.load(fid, **pickle_kwargs)
#     494 except Exception as e:
#
# UnpicklingError: invalid load key, '\xff'.
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 with open('logo.npy','rb') as f:
# ----> 2     logo_rgb_array = np.load(f,allow_pickle = True)
#       3     plt.imshow(logo_rgb_array)
#       4     plt.show
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_npyio_impl.py:495, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     493     return pickle.load(fid, **pickle_kwargs)
#     494 except Exception as e:
# --> 495     raise pickle.UnpicklingError(
#     496         f"Failed to interpret file {file!r} as a pickle") from e
#
# UnpicklingError: Failed to interpret file <_io.BufferedReader name='logo.npy'> as a pickle

# %%
red_array = logo_rgb_array[:,:,0]
blue_array = logo_rgb_array[:,:,1]
green_array = logo_rgb_array[:,:,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 red_array = logo_rgb_array[:,:,0]
#       2 blue_array = logo_rgb_array[:,:,1]
#       3 green_array = logo_rgb_array[:,:,2]
#
# NameError: name 'logo_rgb_array' is not defined
