# %%
import matplotlib.pyplot as plt

# %%
seattle_weather = {
    "months": ["January", "February", "March", "April", "May", "June", 
               "July", "August", "September", "October", "November", "December"],
    "avg_precipitation": [5.6, 4.8, 4.0, 2.5, 1.6, 0.8, 0.4, 0.5, 1.1, 3.2, 5.1, 6.2],
    "precip_25th_percentile": [5.0, 4.2, 3.5, 2.0, 1.2, 0.6, 0.3, 0.4, 0.8, 2.8, 4.6, 5.7],
    "precip_75th_percentile": [6.0, 5.3, 4.5, 3.0, 2.0, 1.0, 0.5, 0.6, 1.5, 3.5, 5.6, 6.7]
}
austin_weather = {
    "months": ["January", "February", "March", "April", "May", "June",
               "July", "August", "September", "October", "November", "December"],
    "avg_precipitation": [2.5, 2.0, 2.4, 2.7, 3.0, 2.8, 2.2, 2.0, 3.0, 3.5, 3.2, 3.0],
    "precip_25th_percentile": [2.0, 1.8, 2.2, 2.4, 2.8, 2.6, 2.0, 1.8, 2.6, 3.2, 2.9, 2.8],
    "precip_75th_percentile": [2.8, 2.2, 2.6, 3.0, 3.2, 3.0, 2.6, 2.4, 3.2, 3.8, 3.5, 3.2]
}
import matplotlib.pyplot as plt 
fig, ax = plt.subplots()
ax.plot(seattle_weather['months'],seattle_weather['precip_25th_percentile'],color='b',linestyle = '--')
ax.plot(seattle_weather['months'],seattle_weather['avg_precipitation'],color='b')
ax.plot(seattle_weather['months'],seattle_weather['precip_75th_percentile'],color='b',linestyle = '--')
ax.plot(austin_weather['months'],austin_weather['precip_25th_percentile'],color='r',linestyle = '--')
ax.plot(austin_weather['months'],austin_weather['avg_precipitation'],color='r')
ax.plot(austin_weather['months'],austin_weather['precip_75th_percentile'],color='r',linestyle = '--')

# Add labels and legend
ax.set_xlabel('Month')
ax.set_ylabel('Precipitation (inches)')
ax.set_title('Monthly Precipitation Data for Seattle and Austin')
ax.legend()

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to fit labels
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1372\2764332081.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fig, ax = plt.subplots(3,2)
# ax[0,0].plot(seattle_weather['months'],seattle_weather['precip_25th_percentile'],color='b',linestyle = '--')
ax[0,0].plot(seattle_weather['months'],seattle_weather['avg_precipitation'],color='b')
# ax[0,0].plot(seattle_weather['months'],seattle_weather['precip_75th_percentile'],color='b',linestyle = '--')

# %%
ax[0,0].plot(seattle_weather['months'],seattle_weather['precip_25th_percentile'],color='b',linestyle = '--')
ax[0,0].plot(seattle_weather['months'],seattle_weather['avg_precipitation'],color='b')
ax[0,0].plot(seattle_weather['months'],seattle_weather['precip_75th_percentile'],color='b',linestyle = '--')

# %%
import matplotlib.pyplot as plt
seattle_weather = {
    "months": ["January", "February", "March", "April", "May", "June", 
               "July", "August", "September", "October", "November", "December"],
    "avg_precipitation": [5.6, 4.8, 4.0, 2.5, 1.6, 0.8, 0.4, 0.5, 1.1, 3.2, 5.1, 6.2],
    "precip_25th_percentile": [5.0, 4.2, 3.5, 2.0, 1.2, 0.6, 0.3, 0.4, 0.8, 2.8, 4.6, 5.7],
    "precip_75th_percentile": [6.0, 5.3, 4.5, 3.0, 2.0, 1.0, 0.5, 0.6, 1.5, 3.5, 5.6, 6.7]
}
austin_weather = {
    "months": ["January", "February", "March", "April", "May", "June",
               "July", "August", "September", "October", "November", "December"],
    "avg_precipitation": [2.5, 2.0, 2.4, 2.7, 3.0, 2.8, 2.2, 2.0, 3.0, 3.5, 3.2, 3.0],
    "precip_25th_percentile": [2.0, 1.8, 2.2, 2.4, 2.8, 2.6, 2.0, 1.8, 2.6, 3.2, 2.9, 2.8],
    "precip_75th_percentile": [2.8, 2.2, 2.6, 3.0, 3.2, 3.0, 2.6, 2.4, 3.2, 3.8, 3.5, 3.2]
}
fig,ax = plt.subplots(2,1,sharey=True)
ax[0].plot(seattle_weather['months'],seattle_weather['precip_25th_percentile'],color='b',linestyle = '--')
ax[0].plot(seattle_weather['months'],seattle_weather['avg_precipitation'],color='b')
ax[0].plot(seattle_weather['months'],seattle_weather['precip_75th_percentile'],color='b',linestyle = '--')
ax[1].plot(austin_weather['months'],austin_weather['precip_25th_percentile'],color='r',linestyle = '--')
ax[1].plot(austin_weather['months'],austin_weather['avg_precipitation'],color='r')
ax[1].plot(austin_weather['months'],austin_weather['precip_75th_percentile'],color='r',linestyle = '--')
ax[1].set_xlabel('Month')
ax[0].set_ylabel('Precipitation (inches)')
ax[1].set_ylabel('Precipitation (inches)')
plt.show()
