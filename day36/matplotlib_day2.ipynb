# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(3,2)
data = {
    "date": [
        "2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05",
        "2024-01-06", "2024-01-07", "2024-01-08", "2024-01-09", "2024-01-10"
    ],
     "avg_temperature": [47.0, 48.0, 50.0, 45.5, 44.5, 43.5, 48.0, 49.0, 47.0, 50.0]
}
data_austin = {
    "date": [
        "2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05",
        "2024-01-06", "2024-01-07", "2024-01-08", "2024-01-09", "2024-01-10"
    ],
    "avg_temperature": [55.0, 56.0, 57.0, 54.5, 53.5, 52.0, 55.0, 56.5, 55.5, 58.0]
}

ax[0,0].plot(data_austin["date"],data_austin["avg_temperature"], marker="o",linestyle = "--",color = "r")
plt.show()

# %%
fig,ax = plt.subplots(2,1, sharey=True)
data = {
    "date": [
        "2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05",
        "2024-01-06", "2024-01-07", "2024-01-08", "2024-01-09", "2024-01-10"
    ],
     "avg_temperature": [47.0, 48.0, 50.0, 45.5, 44.5, 43.5, 48.0, 49.0, 47.0, 50.0]
}
data_austin = {
    "date": [
        "2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05",
        "2024-01-06", "2024-01-07", "2024-01-08", "2024-01-09", "2024-01-10"
    ],
    "avg_temperature": [55.0, 56.0, 57.0, 54.5, 53.5, 52.0, 55.0, 56.5, 55.5, 58.0]
}
ax[0].plot(data["date"],data["avg_temperature"])
ax[1].plot(data_austin["date"],data_austin["avg_temperature"])
plt.show()
